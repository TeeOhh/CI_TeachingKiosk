# %%
import csv
import json
import pandas as pd
import re
import string

from nltk import word_tokenize
from nltk.corpus import stopwords
stops = set(stopwords.words('english'))

import pprint 
pp = pprint.PrettyPrinter(indent=2)

from faculty import scrapeFacultyData

# %%
def fetch_formatted_faculty_data():
    faculty_data = scrapeFacultyData()
    for faculty in faculty_data:
        curr_faculty_name = faculty['name'].strip()
        faculty_name_split = curr_faculty_name.split(' ')

        # get first and last name
        faculty_first_name = faculty_name_split[0]

        # special case for sarah van wart
        if curr_faculty_name == 'Sarah Van Wart':
            faculty_last_name = 'Van Wart'
        else:
            faculty_last_name = faculty_name_split[-1]

        # add name to dict
        faculty['first_name'] = faculty_first_name
        faculty['last_name'] = faculty_last_name

    return faculty_data

# %%
def fetch_and_parse_course_data(filepath):
    # load data
    data = pd.read_csv(filepath)

    # rename columns and remove any unnecessary ones
    data.columns = [name.strip().lower().replace(' ', '_') for name in list(data)]
    data = data[['qtr', 'course', 'title', 'instructor', 'course_topic_area', 'days', 'start', 'end', 'duration']]

    # convert quarter to full name
    data['qtr'].replace({'F': 'Fall', 'W': 'Winter', 'S': 'Spring'}, inplace=True)
    
    # add a year column
    data = data.assign(year=data['qtr'].apply(lambda x: '2019' if x == 'Fall' else '2020'))

    # add a parsed day column
    regex = r"([MWF]|(Tu)|(Th))"
    data['days'] = data['days'].apply(lambda x: [x[0] for x in re.findall(regex, x)])

    # parse instructors
    data['instructor'] = data['instructor'].apply(lambda x: x.split('/') if x != 'STAFF' else [])

    # replace blank course_topic_area with empty string
    data['course_topic_area'].fillna('', inplace=True)
    
    return data

# %%
def format_name(name_str):
    cleaned_str = name_str.strip().title().translate(str.maketrans('', '', string.punctuation))
    tokenized_name = word_tokenize(cleaned_str)
    stops_removed = [i for i in tokenized_name if i.lower() not in stops]
    return ''.join(stops_removed)

def instructor_names(instructors, faculty_list):
    pretty_instructor_names = []
    ontology_instructor_names = []
    
    for instructor in instructors:
        for faculty in faculty_list:
            if instructor.lower().strip() == faculty['last_name'].lower().strip():
                pretty_instructor_names.append(faculty['name'])
                ontology_instructor_names.append(faculty['ID'])
                break
    
    return pretty_instructor_names, ontology_instructor_names

def create_course_list(data, faculty_list):
    course_list = []

    # loop over each course in data
    for index, course in data.iterrows():
        formatted_names, ontology_names = instructor_names(course['instructor'], faculty_list)

        curr_course_dict = {
            'pretty_name': course['title'],
            'formatted_name': format_name(course['title']),
            'course_number': course['course'],
            'quarter_offered': course['qtr'],
            'year_offered': course['year'],
            'formatted_instructors': formatted_names,
            'ontology_instructors': ontology_names,
            'course_topic_area': course['course_topic_area'],
            'class_days': course['days'],
            'start_time': course['start'],
            'end_time': course['end'],
            'class_duration': course['duration']
        }
        course_list.append(curr_course_dict)
    
    return course_list

# %%
def day_abbrev_to_str(day_abbrev):
    cleaned_day_abbrev = day_abbrev.strip().lower()
    
    if cleaned_day_abbrev == 'm':
        return 'Monday'
    if cleaned_day_abbrev == 'tu':
        return 'Tuesday'
    if cleaned_day_abbrev == 'w':
        return 'Wednesday'
    if cleaned_day_abbrev == 'th':
        return 'Thursday'
    if cleaned_day_abbrev == 'f':
        return 'Friday'
    
    return ''

def generate_time_string(days_offered, start_time, end_time):
    # convert day abbreviation to full text string
    day_strs = [day_abbrev_to_str(day) for day in days_offered]
    
    # create and return string
    return '{} from {} to {}'.format('/'.join(day_strs), start_time, end_time)
    

def convert_course_to_krf(course_dict):
    course_krf = []
    
    # setup course name
    course_name = '{}-{}{}'.format(course_dict['formatted_name'],
                                   course_dict['quarter_offered'],
                                   course_dict['year_offered']) 
    course_krf.append('(isa {} NUCourse-CS)'.format(course_name))
    course_krf.append('(courseName {} "{}")'.format(course_name, course_dict['pretty_name']))
    
    # setup course field
    if course_dict['course_topic_area'] != '':
        course_krf.append('(academicTopicOf {} {})'.format(course_name, course_dict['course_topic_area']))
    
    # setup course time
    course_time_str = generate_time_string(course_dict['class_days'], course_dict['start_time'], course_dict['end_time'])
    course_krf.append('(courseTimeString {} "{}")'.format(course_name, course_time_str))
    
    # setup course instructor(s)
    for instructor in course_dict['ontology_instructors']:
        course_krf.append('(courseInstructor {} {})'.format(course_name, instructor))
    
    # setup i/o predicates TODO
#     '(indexedProperName (TheList) 354 {})'.format(course_name)
#     '(indexedProperName (TheList network penetration and) security {})'.format(course_name)
#     '(indexedProperName (TheList cs) 354 {})'.format(course_name)
#     '(indexedProperName (TheList eecs) 354 {})'.format(course_name)
    
    # return combined krf string
    return '\n'.join(course_krf)   
    

def generate_krf_list(course_list):
    return '\n\n'.join([convert_course_to_krf(course_dict) for course_dict in course_list])

# %%
def main():
    input_filepath = '../data/cs-courses_2019-2020.csv'
    output_dir = '../krf'
    
    # get faculty list and courses
    faculty_list = fetch_formatted_faculty_data()
    course_df = fetch_and_parse_course_data(input_filepath)
    
    # create course lists for each quarter separately and export
    qtr_course_info_list = [
        { 'quarter': 'Fall', 'outfile': 'F2019' },
        { 'quarter': 'Winter', 'outfile': 'W2019' },
        { 'quarter': 'Spring', 'outfile': 'S2019' }
    ]
    
    for qtr in qtr_course_info_list:
        curr_qtr_str = qtr['quarter']
        curr_outfile = qtr['outfile']
        curr_course_list = create_course_list(course_df[course_df['qtr'] == curr_qtr_str], faculty_list)
        
        with open('{}/courses-{}.krf'.format(output_dir, curr_outfile), 'w') as f:
            f.write('(in-microtheory TeachingKioskMt)\n\n')
            f.write(generate_krf_list(curr_course_list))
    
    # also export full course list
    full_course_list = create_course_list(course_df, faculty_list)
    with open('{}/courses-2019-2020.krf'.format(output_dir), 'w') as f:
            f.write('(in-microtheory TeachingKioskMt)\n\n')
            f.write(generate_krf_list(full_course_list))

    return create_course_list(course_df, faculty_list)

# %%
course_list = main()
course_list
# Out:
# [{'pretty_name': 'Computer Science: Concepts, Philosophy, and Connections',
#   'formatted_name': 'ComputerScienceConceptsPhilosophyConnections',
#   'course_number': '101',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Larry Birnbaum'],
#   'ontology_instructors': ['LarryBirnbaum'],
#   'course_topic_area': '',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '14:00',
#   'end_time': '14:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro Programming for non-majors',
#   'formatted_name': 'IntroProgrammingNonMajors',
#   'course_number': '110',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Sarah Van Wart'],
#   'ontology_instructors': ['SarahVanWart'],
#   'course_topic_area': '',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '10:00',
#   'end_time': '10:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro Programming for non-majors',
#   'formatted_name': 'IntroProgrammingNonMajors',
#   'course_number': '110',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sarah Van Wart'],
#   'ontology_instructors': ['SarahVanWart'],
#   'course_topic_area': '',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro Programming for non-majors',
#   'formatted_name': 'IntroProgrammingNonMajors',
#   'course_number': '110',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sarah Van Wart'],
#   'ontology_instructors': ['SarahVanWart'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '16:00',
#   'end_time': '17:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Fundamentals of Computer Programming 1',
#   'formatted_name': 'FundamentalsComputerProgramming1',
#   'course_number': '111',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Ian Horswill'],
#   'ontology_instructors': ['IanHorswill'],
#   'course_topic_area': '',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '13:00',
#   'end_time': '13:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Fundamentals of Computer Programming 1',
#   'formatted_name': 'FundamentalsComputerProgramming1',
#   'course_number': '111',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jesse Tov'],
#   'ontology_instructors': ['JesseTov'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Fundamentals of Computer Programming 1',
#   'formatted_name': 'FundamentalsComputerProgramming1',
#   'course_number': '111',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sara Owsley Sood'],
#   'ontology_instructors': ['SaraOwsleySood'],
#   'course_topic_area': '',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Tools and Technologies of the Web',
#   'formatted_name': 'ToolsTechnologiesWeb',
#   'course_number': '130',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sarah Van Wart'],
#   'ontology_instructors': ['SarahVanWart'],
#   'course_topic_area': 'SoftwareDevelopmentTechniques-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '16:00',
#   'end_time': '16:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Fundamentals of Computer Programming 2',
#   'formatted_name': 'FundamentalsComputerProgramming2',
#   'course_number': '211',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Sara Owsley Sood'],
#   'ontology_instructors': ['SaraOwsleySood'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Fundamentals of Computer Programming 2',
#   'formatted_name': 'FundamentalsComputerProgramming2',
#   'course_number': '211',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sara Owsley Sood'],
#   'ontology_instructors': ['SaraOwsleySood'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Fundamentals of Computer Programming 2',
#   'formatted_name': 'FundamentalsComputerProgramming2',
#   'course_number': '211',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jesse Tov'],
#   'ontology_instructors': ['JesseTov'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Discrete math',
#   'formatted_name': 'DiscreteMath',
#   'course_number': '212',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Aravindan Vijayaraghavan'],
#   'ontology_instructors': ['AravindanVijayaraghavan'],
#   'course_topic_area': 'DiscreteMathematics-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '15:00',
#   'end_time': '15:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Discrete math',
#   'formatted_name': 'DiscreteMath',
#   'course_number': '212',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Aravindan Vijayaraghavan'],
#   'ontology_instructors': ['AravindanVijayaraghavan'],
#   'course_topic_area': 'DiscreteMathematics-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '15:00',
#   'end_time': '15:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Discrete math',
#   'formatted_name': 'DiscreteMath',
#   'course_number': '212',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'DiscreteMathematics-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '16:00',
#   'end_time': '16:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro to Computer Systems',
#   'formatted_name': 'IntroComputerSystems',
#   'course_number': '213',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Vincent St-Amour'],
#   'ontology_instructors': ['VincentStAmour'],
#   'course_topic_area': 'SoftwareSystemStructures-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Computer Systems',
#   'formatted_name': 'IntroComputerSystems',
#   'course_number': '213',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Peter Dinda'],
#   'ontology_instructors': ['PeterDinda'],
#   'course_topic_area': 'SoftwareSystemStructures-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Computer Systems',
#   'formatted_name': 'IntroComputerSystems',
#   'course_number': '213',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Nikos Hardavellas'],
#   'ontology_instructors': ['NikosHardavellas'],
#   'course_topic_area': 'SoftwareSystemStructures-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Computer Systems',
#   'formatted_name': 'IntroComputerSystems',
#   'course_number': '213',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Vincent St-Amour'],
#   'ontology_instructors': ['VincentStAmour'],
#   'course_topic_area': 'SoftwareSystemStructures-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Data structures',
#   'formatted_name': 'DataStructures',
#   'course_number': '214',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Jesse Tov'],
#   'ontology_instructors': ['JesseTov'],
#   'course_topic_area': 'DataStructuresDesignAnalysis-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Data structures',
#   'formatted_name': 'DataStructures',
#   'course_number': '214',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Ian Horswill'],
#   'ontology_instructors': ['IanHorswill'],
#   'course_topic_area': 'DataStructuresDesignAnalysis-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '13:00',
#   'end_time': '13:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Data structures',
#   'formatted_name': 'DataStructures',
#   'course_number': '214',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Vincent St-Amour'],
#   'ontology_instructors': ['VincentStAmour'],
#   'course_topic_area': 'DataStructuresDesignAnalysis-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '16:00',
#   'end_time': '17:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Data management and information processing',
#   'formatted_name': 'DataManagementInformationProcessing',
#   'course_number': '217',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'DataManagementSystems-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Data management and information processing',
#   'formatted_name': 'DataManagementInformationProcessing',
#   'course_number': '217',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'DataManagementSystems-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Programming for engineers',
#   'formatted_name': 'ProgrammingEngineers',
#   'course_number': '230',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jesse Tov'],
#   'ontology_instructors': ['JesseTov'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intensive Program Design',
#   'formatted_name': 'IntensiveProgramDesign',
#   'course_number': '295',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Jesse Tov', 'Robby Findler'],
#   'ontology_instructors': ['JesseTov', 'RobbyFindler'],
#   'course_topic_area': 'SoftwareDevelopmentTechniques-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:00',
#   'end_time': '14:50',
#   'class_duration': '2:50'},
#  {'pretty_name': 'Fundamentals of Programming 1.5',
#   'formatted_name': 'FundamentalsProgramming15',
#   'course_number': '295',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sara Owsley Sood'],
#   'ontology_instructors': ['SaraOwsleySood'],
#   'course_topic_area': '',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro to Robotics Laboratory',
#   'formatted_name': 'IntroRoboticsLaboratory',
#   'course_number': '301',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Brenna Argall'],
#   'ontology_instructors': ['BrennaArgall'],
#   'course_topic_area': 'Robotics-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '18:00',
#   'class_duration': '4:00'},
#  {'pretty_name': 'Tangible Interaction Design and Learning',
#   'formatted_name': 'TangibleInteractionDesignLearning',
#   'course_number': '313',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Michael Horn'],
#   'ontology_instructors': ['MichaelHorn'],
#   'course_topic_area': 'InteractionTechniques-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Tech & Human Interaction',
#   'formatted_name': 'TechHumanInteraction',
#   'course_number': '314',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'HumanComputerInteraction-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Design Technology & Research',
#   'formatted_name': 'DesignTechnologyResearch',
#   'course_number': '315',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Haoqi Zhang'],
#   'ontology_instructors': ['HaoqiZhang'],
#   'course_topic_area': 'InteractiveSystemsTools-Topic',
#   'class_days': ['F'],
#   'start_time': '12:00',
#   'end_time': '3:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Design Technology & Research',
#   'formatted_name': 'DesignTechnologyResearch',
#   'course_number': '315',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Haoqi Zhang'],
#   'ontology_instructors': ['HaoqiZhang'],
#   'course_topic_area': 'InteractiveSystemsTools-Topic',
#   'class_days': ['F'],
#   'start_time': '12:00',
#   'end_time': '3:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Design Technology & Research',
#   'formatted_name': 'DesignTechnologyResearch',
#   'course_number': '315',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Haoqi Zhang'],
#   'ontology_instructors': ['HaoqiZhang'],
#   'course_topic_area': 'InteractiveSystemsTools-Topic',
#   'class_days': ['F'],
#   'start_time': '12:00',
#   'end_time': '3:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Programming languages',
#   'formatted_name': 'ProgrammingLanguages',
#   'course_number': '321',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Vincent St-Amour'],
#   'ontology_instructors': ['VincentStAmour'],
#   'course_topic_area': 'GeneralProgrammingLanguages-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Programming languages',
#   'formatted_name': 'ProgrammingLanguages',
#   'course_number': '321',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Vincent St-Amour'],
#   'ontology_instructors': ['VincentStAmour'],
#   'course_topic_area': 'GeneralProgrammingLanguages-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Programming languages',
#   'formatted_name': 'ProgrammingLanguages',
#   'course_number': '321',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Robby Findler'],
#   'ontology_instructors': ['RobbyFindler'],
#   'course_topic_area': 'GeneralProgrammingLanguages-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Compilers',
#   'formatted_name': 'Compilers',
#   'course_number': '322',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Simone Campanoni'],
#   'ontology_instructors': ['SimoneCampanoni'],
#   'course_topic_area': 'Compilers-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Code Analysis and Transformation',
#   'formatted_name': 'CodeAnalysisTransformation',
#   'course_number': '323',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Simone Campanoni'],
#   'ontology_instructors': ['SimoneCampanoni'],
#   'course_topic_area': 'MathematicalOptimization-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Human-Computer Interaction',
#   'formatted_name': 'HumanComputerInteraction',
#   'course_number': '330',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Marcelo Worsley'],
#   'ontology_instructors': ['MarceloWorsley'],
#   'course_topic_area': 'HumanComputerInteraction-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Human-Computer Interaction',
#   'formatted_name': 'HumanComputerInteraction',
#   'course_number': '330',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Michael Horn'],
#   'ontology_instructors': ['MichaelHorn'],
#   'course_topic_area': 'HumanComputerInteraction-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Human-Computer Interaction',
#   'formatted_name': 'HumanComputerInteraction',
#   'course_number': '330',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Sarah Van Wart'],
#   'ontology_instructors': ['SarahVanWart'],
#   'course_topic_area': 'HumanComputerInteraction-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '13:00',
#   'end_time': '13:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro to Computation Phototography',
#   'formatted_name': 'IntroComputationPhototography',
#   'course_number': '331',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Oliver  S. Cossairt'],
#   'ontology_instructors': ['OliverSCossairt'],
#   'course_topic_area': 'ComputationalPhotography-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Design and Analysis of Algorithms',
#   'formatted_name': 'DesignAnalysisAlgorithms',
#   'course_number': '336',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Jason  D. Hartline'],
#   'ontology_instructors': ['JasonDHartline'],
#   'course_topic_area': 'DesignAnalysisAlgorithms-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Design and Analysis of Algorithms',
#   'formatted_name': 'DesignAnalysisAlgorithms',
#   'course_number': '336',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Samir Khuller'],
#   'ontology_instructors': ['SamirKhuller'],
#   'course_topic_area': 'DesignAnalysisAlgorithms-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Design and Analysis of Algorithms',
#   'formatted_name': 'DesignAnalysisAlgorithms',
#   'course_number': '336',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Konstantin Makarychev'],
#   'ontology_instructors': ['KonstantinMakarychev'],
#   'course_topic_area': 'DesignAnalysisAlgorithms-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Natural Language Processing',
#   'formatted_name': 'IntroNaturalLanguageProcessing',
#   'course_number': '337',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Larry Birnbaum'],
#   'ontology_instructors': ['LarryBirnbaum'],
#   'course_topic_area': 'NaturalLanguageProcessing-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Practicum in Intelligence Information Systems',
#   'formatted_name': 'PracticumIntelligenceInformationSystems',
#   'course_number': '338',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Larry Birnbaum'],
#   'ontology_instructors': ['LarryBirnbaum'],
#   'course_topic_area': 'InformationSystems-Topic',
#   'class_days': ['W'],
#   'start_time': '6:00',
#   'end_time': '9:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Practicum in Intelligence Information Systems',
#   'formatted_name': 'PracticumIntelligenceInformationSystems',
#   'course_number': '338',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Larry Birnbaum'],
#   'ontology_instructors': ['LarryBirnbaum'],
#   'course_topic_area': 'InformationSystems-Topic',
#   'class_days': ['M'],
#   'start_time': '6:00',
#   'end_time': '9:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Intro to Databases',
#   'formatted_name': 'IntroDatabases',
#   'course_number': '339',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jennie  M. Rogers'],
#   'ontology_instructors': ['JennieMRogers'],
#   'course_topic_area': 'DatabaseManagementSystemEngines-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Databases',
#   'formatted_name': 'IntroDatabases',
#   'course_number': '339',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jennie  M. Rogers'],
#   'ontology_instructors': ['JennieMRogers'],
#   'course_topic_area': 'DatabaseManagementSystemEngines-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Networking',
#   'formatted_name': 'Networking',
#   'course_number': '340',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Fabian  E. Bustamante'],
#   'ontology_instructors': ['FabianEBustamante'],
#   'course_topic_area': 'Networks-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Networking',
#   'formatted_name': 'Networking',
#   'course_number': '340',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Stephen Tarzia'],
#   'ontology_instructors': ['StephenTarzia'],
#   'course_topic_area': 'Networks-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '13:00',
#   'end_time': '13:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Operating Systems',
#   'formatted_name': 'OperatingSystems',
#   'course_number': '343',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Stephen Tarzia'],
#   'ontology_instructors': ['StephenTarzia'],
#   'course_topic_area': 'OperatingSystemsSecurity-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '13:00',
#   'end_time': '13:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Operating Systems',
#   'formatted_name': 'OperatingSystems',
#   'course_number': '343',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Peter Dinda'],
#   'ontology_instructors': ['PeterDinda'],
#   'course_topic_area': 'OperatingSystemsSecurity-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Distributed Systems',
#   'formatted_name': 'DistributedSystems',
#   'course_number': '345',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Fabian  E. Bustamante'],
#   'ontology_instructors': ['FabianEBustamante'],
#   'course_topic_area': 'DistributedArchitectures-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:00',
#   'end_time': '10:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Artificial Intelligence',
#   'formatted_name': 'IntroArtificialIntelligence',
#   'course_number': '348',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Kristian  J. Hammond'],
#   'ontology_instructors': ['KristianJHammond'],
#   'course_topic_area': 'ArtificialIntelligence-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '16:00',
#   'end_time': '16:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro to Artificial Intelligence',
#   'formatted_name': 'IntroArtificialIntelligence',
#   'course_number': '348',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Michael Rubenstein'],
#   'ontology_instructors': ['MichaelRubenstein'],
#   'course_topic_area': 'ArtificialIntelligence-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Intro to Artificial Intelligence',
#   'formatted_name': 'IntroArtificialIntelligence',
#   'course_number': '348',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'ArtificialIntelligence-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '15:00',
#   'end_time': '15:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Machine Learning',
#   'formatted_name': 'MachineLearning',
#   'course_number': '349',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Bryan Pardo'],
#   'ontology_instructors': ['BryanPardo'],
#   'course_topic_area': 'MachineLearning-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Machine Learning',
#   'formatted_name': 'MachineLearning',
#   'course_number': '349',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Bryan Pardo'],
#   'ontology_instructors': ['BryanPardo'],
#   'course_topic_area': 'MachineLearning-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Network Penetration and Security',
#   'formatted_name': 'NetworkPenetrationSecurity',
#   'course_number': '354',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Yan Chen'],
#   'ontology_instructors': ['YanChen'],
#   'course_topic_area': 'NetworkSecurity-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Game Design and Development',
#   'formatted_name': 'GameDesignDevelopment',
#   'course_number': '376',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Ian Horswill'],
#   'ontology_instructors': ['IanHorswill'],
#   'course_topic_area': 'DesigningSoftware-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '15:00',
#   'end_time': '15:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Software Construction',
#   'formatted_name': 'SoftwareConstruction',
#   'course_number': '393',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Christos Dimoulas'],
#   'ontology_instructors': ['ChristosDimoulas'],
#   'course_topic_area': 'SoftwareDevelopmentTechniques-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Software Project Management and Development',
#   'formatted_name': 'SoftwareProjectManagementDevelopment',
#   'course_number': '394',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Chris Riesbeck'],
#   'ontology_instructors': ['ChrisRiesbeck'],
#   'course_topic_area': 'SoftwareDevelopmentProcessManagement-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Software Project Management and Development',
#   'formatted_name': 'SoftwareProjectManagementDevelopment',
#   'course_number': '394',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Chris Riesbeck'],
#   'ontology_instructors': ['ChrisRiesbeck'],
#   'course_topic_area': 'SoftwareDevelopmentProcessManagement-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Interactive Information Visualization',
#   'formatted_name': 'InteractiveInformationVisualization',
#   'course_number': '396',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Jessica Hullman'],
#   'ontology_instructors': ['JessicaHullman'],
#   'course_topic_area': 'VisualizationTechniques-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Scalable software architectures',
#   'formatted_name': 'ScalableSoftwareArchitectures',
#   'course_number': '396',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Stephen Tarzia'],
#   'ontology_instructors': ['StephenTarzia'],
#   'course_topic_area': 'LargeScaleIntegrationDesign-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Swarms and Multi-Robot Systems',
#   'formatted_name': 'SwarmsMultiRobotSystems',
#   'course_number': '396',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Michael Rubenstein'],
#   'ontology_instructors': ['MichaelRubenstein'],
#   'course_topic_area': 'Robotics-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:00',
#   'end_time': '15:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Data Science Seminar',
#   'formatted_name': 'DataScienceSeminar',
#   'course_number': '396',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Jennie  M. Rogers'],
#   'ontology_instructors': ['JennieMRogers'],
#   'course_topic_area': 'DataManagementSystems-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Operational Semantics',
#   'formatted_name': 'OperationalSemantics',
#   'course_number': '396',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Christos Dimoulas'],
#   'ontology_instructors': ['ChristosDimoulas'],
#   'course_topic_area': 'ProgramSemantics-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Systems Programming in Rust',
#   'formatted_name': 'SystemsProgrammingRust',
#   'course_number': '396',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jesse Tov'],
#   'ontology_instructors': ['JesseTov'],
#   'course_topic_area': 'GeneralProgrammingLanguages-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Affective Computing Seminar',
#   'formatted_name': 'AffectiveComputingSeminar',
#   'course_number': '396',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'ArtificialIntelligence-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'TBD',
#   'formatted_name': 'Tbd',
#   'course_number': '396',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Robby Findler'],
#   'ontology_instructors': ['RobbyFindler'],
#   'course_topic_area': '',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Topics in Software Engineering',
#   'formatted_name': 'TopicsSoftwareEngineering',
#   'course_number': '396',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Vincent St-Amour'],
#   'ontology_instructors': ['VincentStAmour'],
#   'course_topic_area': 'SoftwareEngineering-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '3:30',
#   'end_time': '4:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Online Markets',
#   'formatted_name': 'OnlineMarkets',
#   'course_number': '396',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jason  D. Hartline'],
#   'ontology_instructors': ['JasonDHartline'],
#   'course_topic_area': 'TheoryComputation-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Introduction to cryptography',
#   'formatted_name': 'IntroductionCryptography',
#   'course_number': '396',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Xiao Wang'],
#   'ontology_instructors': ['XiaoWang'],
#   'course_topic_area': 'Cryptography-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Quadrotor design and control',
#   'formatted_name': 'QuadrotorDesignControl',
#   'course_number': '396',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Michael Rubenstein'],
#   'ontology_instructors': ['MichaelRubenstein'],
#   'course_topic_area': 'Robotics-Topic',
#   'class_days': ['Th'],
#   'start_time': '13:00',
#   'end_time': '16:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Programming Language Seminar',
#   'formatted_name': 'ProgrammingLanguageSeminar',
#   'course_number': '396',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Christos Dimoulas'],
#   'ontology_instructors': ['ChristosDimoulas'],
#   'course_topic_area': 'lProgrammingLanguages-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '12:30',
#   'end_time': '13:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Advanced topics in compilers',
#   'formatted_name': 'AdvancedTopicsCompilers',
#   'course_number': '397',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Simone Campanoni'],
#   'ontology_instructors': ['SimoneCampanoni'],
#   'course_topic_area': 'Compilers-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Innovation in Journalism',
#   'formatted_name': 'InnovationJournalism',
#   'course_number': '397',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Kristian  J. Hammond'],
#   'ontology_instructors': ['KristianJHammond'],
#   'course_topic_area': 'SoftwareEngineering-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '14:30',
#   'end_time': '16:20',
#   'class_duration': '2:20'},
#  {'pretty_name': 'Inclusive Making',
#   'formatted_name': 'InclusiveMaking',
#   'course_number': '397',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Marcelo Worsley'],
#   'ontology_instructors': ['MarceloWorsley'],
#   'course_topic_area': 'Accessibility-Topic',
#   'class_days': ['Tu'],
#   'start_time': '9:30',
#   'end_time': '12:20',
#   'class_duration': '2:50'},
#  {'pretty_name': 'Computational Creativity',
#   'formatted_name': 'ComputationalCreativity',
#   'course_number': '397',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Bryan Pardo'],
#   'ontology_instructors': ['BryanPardo'],
#   'course_topic_area': 'ArtsHumanities-Topic',
#   'class_days': ['Th'],
#   'start_time': '13:00',
#   'end_time': '16:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Rapid Prototyping for Software Innovation',
#   'formatted_name': 'RapidPrototypingSoftwareInnovation',
#   'course_number': '397',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Sarah Van Wart'],
#   'ontology_instructors': ['SarahVanWart'],
#   'course_topic_area': 'SoftwareDevelopmentProcessManagement-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '13:00',
#   'end_time': '13:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Digital Musical Instrument Design',
#   'formatted_name': 'DigitalMusicalInstrumentDesign',
#   'course_number': '397',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Bryan Pardo'],
#   'ontology_instructors': ['BryanPardo'],
#   'course_topic_area': 'SoundMusicComputing-Topic',
#   'class_days': ['M'],
#   'start_time': '3:00',
#   'end_time': '6:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Comp. Photography Seminar',
#   'formatted_name': 'CompPhotographySeminar',
#   'course_number': '397',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Oliver  S. Cossairt'],
#   'ontology_instructors': ['OliverSCossairt'],
#   'course_topic_area': 'ComputationalPhotography-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '16:00',
#   'end_time': '19:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Game Design Studio',
#   'formatted_name': 'GameDesignStudio',
#   'course_number': '397',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'DesigningSoftware-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '18:00',
#   'end_time': '19:30',
#   'class_duration': '1:30'},
#  {'pretty_name': 'Digital Forensics',
#   'formatted_name': 'DigitalForensics',
#   'course_number': '397',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Yan Chen'],
#   'ontology_instructors': ['YanChen'],
#   'course_topic_area': 'SecurityPrivacy-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '10:00',
#   'end_time': '11:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Internet-Scale Experimentation',
#   'formatted_name': 'InternetScaleExperimentation',
#   'course_number': '397',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Fabian  E. Bustamante'],
#   'ontology_instructors': ['FabianEBustamante'],
#   'course_topic_area': 'NetworkExperimentation-Topic',
#   'class_days': ['M', 'W'],
#   'start_time': '10:00',
#   'end_time': '13:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'Wireless and Mobile Health',
#   'formatted_name': 'WirelessMobileHealth',
#   'course_number': '397',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'DesigningSoftware-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '5:00',
#   'end_time': '6:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Kernel and Other Low-level Software Development',
#   'formatted_name': 'KernelLowLevelSoftwareDevelopment',
#   'course_number': '446',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Peter Dinda'],
#   'ontology_instructors': ['PeterDinda'],
#   'course_topic_area': 'EmbeddedSystems-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Internet Security',
#   'formatted_name': 'InternetSecurity',
#   'course_number': '450',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Yan Chen'],
#   'ontology_instructors': ['YanChen'],
#   'course_topic_area': 'NetworkSecurity-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '15:30',
#   'end_time': '16:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Machine Learning & Artificial Intelligence for Robotics',
#   'formatted_name': 'MachineLearningArtificialIntelligenceRobotics',
#   'course_number': '469',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Brenna Argall'],
#   'ontology_instructors': ['BrennaArgall'],
#   'course_topic_area': 'Robotics-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '11:00',
#   'end_time': '12:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Graduate Complexity',
#   'formatted_name': 'GraduateComplexity',
#   'course_number': '496',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': [],
#   'ontology_instructors': [],
#   'course_topic_area': 'ComputationalComplexityCryptography-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '10:00',
#   'end_time': '11:20',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Modern cryptography',
#   'formatted_name': 'ModernCryptography',
#   'course_number': '496',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Xiao Wang'],
#   'ontology_instructors': ['XiaoWang'],
#   'course_topic_area': 'Cryptography-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Advanced topics in Theoretical CS',
#   'formatted_name': 'AdvancedTopicsTheoreticalCs',
#   'course_number': '496',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Aravindan Vijayaraghavan'],
#   'ontology_instructors': ['AravindanVijayaraghavan'],
#   'course_topic_area': 'TheoryComputation-Topic',
#   'class_days': ['F'],
#   'start_time': '10:00',
#   'end_time': '12:30',
#   'class_duration': '2:50'},
#  {'pretty_name': 'Special Topics in Game AI',
#   'formatted_name': 'SpecialTopicsGameAi',
#   'course_number': '496',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Ian Horswill'],
#   'ontology_instructors': ['IanHorswill'],
#   'course_topic_area': 'ArtificialIntelligence-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '16:00',
#   'end_time': '16:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Grad Algorithms',
#   'formatted_name': 'GradAlgorithms',
#   'course_number': '496',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Konstantin Makarychev'],
#   'ontology_instructors': ['KonstantinMakarychev'],
#   'course_topic_area': 'DesignAnalysisAlgorithms-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Advanced Topics in Approximation Algorithms',
#   'formatted_name': 'AdvancedTopicsApproximationAlgorithms',
#   'course_number': '496',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Konstantin Makarychev'],
#   'ontology_instructors': ['KonstantinMakarychev'],
#   'course_topic_area': 'ApproximationAlgorithmsAnalysis-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '15:00',
#   'end_time': '15:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Advanced Topics in Mechanism Design',
#   'formatted_name': 'AdvancedTopicsMechanismDesign',
#   'course_number': '496',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jason  D. Hartline'],
#   'ontology_instructors': ['JasonDHartline'],
#   'course_topic_area': 'AlgorithmicGameTheoryMechanismDesign-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'Artificial Intelligence Programming',
#   'formatted_name': 'ArtificialIntelligenceProgramming',
#   'course_number': '325-1',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Chris Riesbeck'],
#   'ontology_instructors': ['ChrisRiesbeck'],
#   'course_topic_area': 'ArtificialIntelligence-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '11:00',
#   'end_time': '11:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intro to Computer Graphics',
#   'formatted_name': 'IntroComputerGraphics',
#   'course_number': '351-1',
#   'quarter_offered': 'Fall',
#   'year_offered': '2019',
#   'formatted_instructors': ['Jack  E. Tumblin'],
#   'ontology_instructors': ['JackETumblin'],
#   'course_topic_area': 'ComputerGraphics-Topic',
#   'class_days': ['M', 'W', 'F'],
#   'start_time': '10:00',
#   'end_time': '10:50',
#   'class_duration': '0:50'},
#  {'pretty_name': 'Intermediate Computer Graphics',
#   'formatted_name': 'IntermediateComputerGraphics',
#   'course_number': '351-2',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Jack  E. Tumblin'],
#   'ontology_instructors': ['JackETumblin'],
#   'course_topic_area': 'ComputerGraphics-Topic',
#   'class_days': ['Tu', 'Th'],
#   'start_time': '9:30',
#   'end_time': '10:50',
#   'class_duration': '1:20'},
#  {'pretty_name': 'NUVention Web+Media',
#   'formatted_name': 'NuventionWebMedia',
#   'course_number': '473-1',
#   'quarter_offered': 'Winter',
#   'year_offered': '2020',
#   'formatted_instructors': ['Chris Riesbeck'],
#   'ontology_instructors': ['ChrisRiesbeck'],
#   'course_topic_area': 'SoftwareEngineering-Topic',
#   'class_days': ['Tu'],
#   'start_time': '14:00',
#   'end_time': '17:00',
#   'class_duration': '3:00'},
#  {'pretty_name': 'NUVention Web+Media',
#   'formatted_name': 'NuventionWebMedia',
#   'course_number': '473-2',
#   'quarter_offered': 'Spring',
#   'year_offered': '2020',
#   'formatted_instructors': ['Chris Riesbeck'],
#   'ontology_instructors': ['ChrisRiesbeck'],
#   'course_topic_area': 'SoftwareEngineering-Topic',
#   'class_days': ['Tu'],
#   'start_time': '14:00',
#   'end_time': '17:10',
#   'class_duration': '3:10'}]

# %%
pp.pprint(course_list[0])
# Out:
# { 'class_days': ['M', 'W', 'F'],
#   'class_duration': '0:50',
#   'course_number': '101',
#   'course_topic_area': '',
#   'end_time': '14:50',
#   'formatted_instructors': ['Larry Birnbaum'],
#   'formatted_name': 'ComputerScienceConceptsPhilosophyConnections',
#   'ontology_instructors': ['LarryBirnbaum'],
#   'pretty_name': 'Computer Science: Concepts, Philosophy, and Connections',
#   'quarter_offered': 'Fall',
#   'start_time': '14:00',
#   'year_offered': '2019'}
