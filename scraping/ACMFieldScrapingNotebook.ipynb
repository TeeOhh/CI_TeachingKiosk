# %% [markdown]
# # Load in Libraries

# %%
# data loading and manipulation
import os
import requests

import bs4 as bs

import string
import re
from nltk.corpus import stopwords
stops = set(stopwords.words("english"))

import urllib.request
import ssl
import html5lib
context = ssl._create_unverified_context()

# %% [markdown]
# # Scrape Data for CS Fields of Study
# Use ACM CCS as field classifications: https://dl.acm.org/ccs/ccs_flat.cfm#10003120

# %%
# check if source is already downloaded
css_source_file = './acm_ccs_source.txt'
ccs_source = ''

if os.path.isfile(css_source_file):
    with open(css_source_file, 'r') as f:
        ccs_source = f.read(); 
else:
    acm_ccs_url = 'https://dl.acm.org/ccs/ccs_flat.cfm#10003120'
    ccs_source = urllib.request.urlopen(acm_ccs_url, context=context).read()

ccs_parsed = bs.BeautifulSoup(ccs_source, 'html5lib')

# %%
# from https://stackoverflow.com/questions/17850121/parsing-nested-html-list-with-beautifulsoup
def dictify(ul, parent):
    result = []
    for li in ul.find_all('li', recursive=False):
        key = next(li.stripped_strings)
        ul = li.find('ul')
        if ul:
            result.append({
                'name': key,
                'children': dictify(ul, key)
            })
    return result

def max_depth(tree, curr_depth):
    # base case: no more children
    if len(tree) == 0:
        return curr_depth
    
    # recurse deeper
    curr_max_depth = curr_depth
    for child in tree:
        new_max_depth = max_depth(child['children'], curr_depth + 1)
        if new_max_depth > curr_max_depth:
            curr_max_depth = new_max_depth
    
    return curr_max_depth

def get_nodes_at_depth(tree, parent, curr_depth, desired_depth):
    """
    Gets nodes at the desired depth level.
    """
    # base case: no more children or depth limit reached
    if len(tree) == 0 or curr_depth > desired_depth:
        return
    
    # recurse deeper
    if curr_depth == desired_depth:
        print('Nodes for {}'.format(parent))
    for child in tree:
        if curr_depth == desired_depth:
            print(child['name'])
        get_nodes_at_depth(child['children'], child['name'], curr_depth + 1, desired_depth)
    
    print()
    return

# %%
def index_of_key(list_of_dicts, field, target):
    for index, curr_dict in enumerate(list_of_dicts):
        if curr_dict[field] == target: 
            return index

# %%
def add_parent(tree, curr_parent=None):
    # base case: no more children
    if len(tree) == 0:
        return
    
    for child in tree:
        # set current parent
        child['parent'] = curr_parent
        
        # recurse deeper
        new_max_depth = add_parent(child['children'], curr_parent=child['name'])
    
    return

# %%
# generate output from html parse tree
flat_content = ccs_parsed.find('div', id='holdflat').ul
output = dictify(flat_content, None)

# remove general and reference
output = [x for x in output if x['name'] != 'General and reference']

# add all subfields of HCI into HCI, and replace hcc with hci
hcc_index = index_of_key(output, 'name', 'Human-centered computing')
hci_index = index_of_key(output[hcc_index]['children'], 'name', 'Human computer interaction (HCI)')

new_hci_children = [child for index, child in enumerate(output[hcc_index]['children']) if index != hci_index]
output[hcc_index]['children'][hci_index]['children'] += new_hci_children

# remove human-centered computing and replace with hci
output[hcc_index] = output[hcc_index]['children'][hci_index]

# combine stuff under AI and make its own top-level grouping
comp_method_index = index_of_key(output, 'name', 'Computing methodologies')
ai_index = index_of_key(output[comp_method_index]['children'], 'name', 'Artificial intelligence')
symb_index = index_of_key(output[comp_method_index]['children'], 'name', 'Symbolic and algebraic manipulation')
ml_index = index_of_key(output[comp_method_index]['children'], 'name', 'Machine learning')
modeling_index = index_of_key(output[comp_method_index]['children'], 'name', 'Modeling and simulation')

output[comp_method_index]['children'][ai_index]['children'] += [output[comp_method_index]['children'][symb_index],
                                                                output[comp_method_index]['children'][ml_index],
                                                                output[comp_method_index]['children'][modeling_index]]
output += [output[comp_method_index]['children'][ai_index]]

# add others from Computing methodologies
output += [child for index, child in enumerate(output[comp_method_index]['children'])
           if index not in set([ai_index, symb_index, ml_index, modeling_index])] 

# delete Computing methodologies
del output[comp_method_index]

# add parents
add_parent(output)

# show final output
output
# Out:
# [{'name': 'Hardware',
#   'children': [{'name': 'Printed circuit boards',
#     'children': [{'name': 'Electromagnetic interference and compatibility',
#       'children': [],
#       'parent': 'Printed circuit boards'},
#      {'name': 'PCB design and layout',
#       'children': [],
#       'parent': 'Printed circuit boards'}],
#     'parent': 'Hardware'},
#    {'name': 'Communication hardware, interfaces and storage',
#     'children': [{'name': 'Signal processing systems',
#       'children': [{'name': 'Digital signal processing',
#         'children': [],
#         'parent': 'Signal processing systems'},
#        {'name': 'Beamforming',
#         'children': [],
#         'parent': 'Signal processing systems'},
#        {'name': 'Noise reduction',
#         'children': [],
#         'parent': 'Signal processing systems'}],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Sensors and actuators',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Buses and high-speed links',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Displays and imagers',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'External storage',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Networking hardware',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Printers',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Sensor applications and deployments',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Sensor devices and platforms',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Sound-based input / output',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Tactile and hand-based interfaces',
#       'children': [{'name': 'Touch screens',
#         'children': [],
#         'parent': 'Tactile and hand-based interfaces'},
#        {'name': 'Haptic devices',
#         'children': [],
#         'parent': 'Tactile and hand-based interfaces'}],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Scanners',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Wireless devices',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Wireless integrated network sensors',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'},
#      {'name': 'Electro-mechanical devices',
#       'children': [],
#       'parent': 'Communication hardware, interfaces and storage'}],
#     'parent': 'Hardware'},
#    {'name': 'Integrated circuits',
#     'children': [{'name': '3D integrated circuits',
#       'children': [],
#       'parent': 'Integrated circuits'},
#      {'name': 'Interconnect',
#       'children': [{'name': 'Input / output circuits',
#         'children': [],
#         'parent': 'Interconnect'},
#        {'name': 'Metallic interconnect',
#         'children': [],
#         'parent': 'Interconnect'},
#        {'name': 'Photonic and optical interconnect',
#         'children': [],
#         'parent': 'Interconnect'},
#        {'name': 'Radio frequency and wireless interconnect',
#         'children': [],
#         'parent': 'Interconnect'}],
#       'parent': 'Integrated circuits'},
#      {'name': 'Semiconductor memory',
#       'children': [{'name': 'Dynamic memory',
#         'children': [],
#         'parent': 'Semiconductor memory'},
#        {'name': 'Static memory',
#         'children': [],
#         'parent': 'Semiconductor memory'},
#        {'name': 'Non-volatile memory',
#         'children': [],
#         'parent': 'Semiconductor memory'},
#        {'name': 'Read-only memory',
#         'children': [],
#         'parent': 'Semiconductor memory'}],
#       'parent': 'Integrated circuits'},
#      {'name': 'Digital switches',
#       'children': [{'name': 'Transistors',
#         'children': [],
#         'parent': 'Digital switches'},
#        {'name': 'Logic families',
#         'children': [],
#         'parent': 'Digital switches'}],
#       'parent': 'Integrated circuits'},
#      {'name': 'Logic circuits',
#       'children': [{'name': 'Arithmetic and datapath circuits',
#         'children': [],
#         'parent': 'Logic circuits'},
#        {'name': 'Asynchronous circuits',
#         'children': [],
#         'parent': 'Logic circuits'},
#        {'name': 'Combinational circuits',
#         'children': [],
#         'parent': 'Logic circuits'},
#        {'name': 'Design modules and hierarchy',
#         'children': [],
#         'parent': 'Logic circuits'},
#        {'name': 'Finite state machines',
#         'children': [],
#         'parent': 'Logic circuits'},
#        {'name': 'Sequential circuits',
#         'children': [],
#         'parent': 'Logic circuits'}],
#       'parent': 'Integrated circuits'},
#      {'name': 'Reconfigurable logic and FPGAs',
#       'children': [{'name': 'Hardware accelerators',
#         'children': [],
#         'parent': 'Reconfigurable logic and FPGAs'},
#        {'name': 'High-speed input / output',
#         'children': [],
#         'parent': 'Reconfigurable logic and FPGAs'},
#        {'name': 'Programmable logic elements',
#         'children': [],
#         'parent': 'Reconfigurable logic and FPGAs'},
#        {'name': 'Programmable interconnect',
#         'children': [],
#         'parent': 'Reconfigurable logic and FPGAs'},
#        {'name': 'Reconfigurable logic applications',
#         'children': [],
#         'parent': 'Reconfigurable logic and FPGAs'},
#        {'name': 'Evolvable hardware',
#         'children': [],
#         'parent': 'Reconfigurable logic and FPGAs'}],
#       'parent': 'Integrated circuits'}],
#     'parent': 'Hardware'},
#    {'name': 'Very large scale integration design',
#     'children': [{'name': '3D integrated circuits',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Analog and mixed-signal circuits',
#       'children': [{'name': 'Data conversion',
#         'children': [],
#         'parent': 'Analog and mixed-signal circuits'},
#        {'name': 'Clock generation and timing',
#         'children': [],
#         'parent': 'Analog and mixed-signal circuits'},
#        {'name': 'Analog and mixed-signal circuit optimization',
#         'children': [],
#         'parent': 'Analog and mixed-signal circuits'},
#        {'name': 'Radio frequency and wireless circuits',
#         'children': [],
#         'parent': 'Analog and mixed-signal circuits'},
#        {'name': 'Wireline communication',
#         'children': [],
#         'parent': 'Analog and mixed-signal circuits'},
#        {'name': 'Analog and mixed-signal circuit synthesis',
#         'children': [],
#         'parent': 'Analog and mixed-signal circuits'}],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Application-specific VLSI designs',
#       'children': [{'name': 'Application specific integrated circuits',
#         'children': [],
#         'parent': 'Application-specific VLSI designs'},
#        {'name': 'Application specific instruction set processors',
#         'children': [],
#         'parent': 'Application-specific VLSI designs'},
#        {'name': 'Application specific processors',
#         'children': [],
#         'parent': 'Application-specific VLSI designs'}],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Design reuse and communication-based design',
#       'children': [{'name': 'Network on chip',
#         'children': [],
#         'parent': 'Design reuse and communication-based design'},
#        {'name': 'System on a chip',
#         'children': [],
#         'parent': 'Design reuse and communication-based design'},
#        {'name': 'Platform-based design',
#         'children': [],
#         'parent': 'Design reuse and communication-based design'},
#        {'name': 'Hard and soft IP',
#         'children': [],
#         'parent': 'Design reuse and communication-based design'}],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Design rules',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Economics of chip design and manufacturing',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Full-custom circuits',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'VLSI design manufacturing considerations',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'On-chip resource management',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'On-chip sensors',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'Standard cell libraries',
#       'children': [],
#       'parent': 'Very large scale integration design'},
#      {'name': 'VLSI packaging',
#       'children': [{'name': 'Die and wafer stacking',
#         'children': [],
#         'parent': 'VLSI packaging'},
#        {'name': 'Input / output styles',
#         'children': [],
#         'parent': 'VLSI packaging'},
#        {'name': 'Multi-chip modules',
#         'children': [],
#         'parent': 'VLSI packaging'},
#        {'name': 'Package-level interconnect',
#         'children': [],
#         'parent': 'VLSI packaging'}],
#       'parent': 'Very large scale integration design'},
#      {'name': 'VLSI system specification and constraints',
#       'children': [],
#       'parent': 'Very large scale integration design'}],
#     'parent': 'Hardware'},
#    {'name': 'Power and energy',
#     'children': [{'name': 'Thermal issues',
#       'children': [{'name': 'Temperature monitoring',
#         'children': [],
#         'parent': 'Thermal issues'},
#        {'name': 'Temperature simulation and estimation',
#         'children': [],
#         'parent': 'Thermal issues'},
#        {'name': 'Temperature control',
#         'children': [],
#         'parent': 'Thermal issues'},
#        {'name': 'Temperature optimization',
#         'children': [],
#         'parent': 'Thermal issues'}],
#       'parent': 'Power and energy'},
#      {'name': 'Energy generation and storage',
#       'children': [{'name': 'Batteries',
#         'children': [],
#         'parent': 'Energy generation and storage'},
#        {'name': 'Fuel-based energy',
#         'children': [],
#         'parent': 'Energy generation and storage'},
#        {'name': 'Renewable energy',
#         'children': [],
#         'parent': 'Energy generation and storage'},
#        {'name': 'Reusable energy storage',
#         'children': [],
#         'parent': 'Energy generation and storage'}],
#       'parent': 'Power and energy'},
#      {'name': 'Energy distribution',
#       'children': [{'name': 'Energy metering',
#         'children': [],
#         'parent': 'Energy distribution'},
#        {'name': 'Power conversion',
#         'children': [],
#         'parent': 'Energy distribution'},
#        {'name': 'Power networks',
#         'children': [],
#         'parent': 'Energy distribution'},
#        {'name': 'Smart grid',
#         'children': [],
#         'parent': 'Energy distribution'}],
#       'parent': 'Power and energy'},
#      {'name': 'Impact on the environment',
#       'children': [],
#       'parent': 'Power and energy'},
#      {'name': 'Power estimation and optimization',
#       'children': [{'name': 'Switching devices power issues',
#         'children': [],
#         'parent': 'Power estimation and optimization'},
#        {'name': 'Interconnect power issues',
#         'children': [],
#         'parent': 'Power estimation and optimization'},
#        {'name': 'Circuits power issues',
#         'children': [],
#         'parent': 'Power estimation and optimization'},
#        {'name': 'Chip-level power issues',
#         'children': [],
#         'parent': 'Power estimation and optimization'},
#        {'name': 'Platform power issues',
#         'children': [],
#         'parent': 'Power estimation and optimization'},
#        {'name': 'Enterprise level and data centers power issues',
#         'children': [],
#         'parent': 'Power estimation and optimization'}],
#       'parent': 'Power and energy'}],
#     'parent': 'Hardware'},
#    {'name': 'Electronic design automation',
#     'children': [{'name': 'High-level and register-transfer level synthesis',
#       'children': [{'name': 'Datapath optimization',
#         'children': [],
#         'parent': 'High-level and register-transfer level synthesis'},
#        {'name': 'Hardware-software codesign',
#         'children': [],
#         'parent': 'High-level and register-transfer level synthesis'},
#        {'name': 'Resource binding and sharing',
#         'children': [],
#         'parent': 'High-level and register-transfer level synthesis'},
#        {'name': 'Operations scheduling',
#         'children': [],
#         'parent': 'High-level and register-transfer level synthesis'}],
#       'parent': 'Electronic design automation'},
#      {'name': 'Hardware description languages and compilation',
#       'children': [],
#       'parent': 'Electronic design automation'},
#      {'name': 'Logic synthesis',
#       'children': [{'name': 'Combinational synthesis',
#         'children': [],
#         'parent': 'Logic synthesis'},
#        {'name': 'Circuit optimization',
#         'children': [],
#         'parent': 'Logic synthesis'},
#        {'name': 'Sequential synthesis',
#         'children': [],
#         'parent': 'Logic synthesis'},
#        {'name': 'Technology-mapping',
#         'children': [],
#         'parent': 'Logic synthesis'},
#        {'name': 'Transistor-level synthesis',
#         'children': [],
#         'parent': 'Logic synthesis'}],
#       'parent': 'Electronic design automation'},
#      {'name': 'Modeling and parameter extraction',
#       'children': [],
#       'parent': 'Electronic design automation'},
#      {'name': 'Physical design (EDA)',
#       'children': [{'name': 'Clock-network synthesis',
#         'children': [],
#         'parent': 'Physical design (EDA)'},
#        {'name': 'Packaging',
#         'children': [],
#         'parent': 'Physical design (EDA)'},
#        {'name': 'Partitioning and floorplanning',
#         'children': [],
#         'parent': 'Physical design (EDA)'},
#        {'name': 'Placement',
#         'children': [],
#         'parent': 'Physical design (EDA)'},
#        {'name': 'Physical synthesis',
#         'children': [],
#         'parent': 'Physical design (EDA)'},
#        {'name': 'Power grid design',
#         'children': [],
#         'parent': 'Physical design (EDA)'},
#        {'name': 'Wire routing',
#         'children': [],
#         'parent': 'Physical design (EDA)'}],
#       'parent': 'Electronic design automation'},
#      {'name': 'Timing analysis',
#       'children': [{'name': 'Electrical-level simulation',
#         'children': [],
#         'parent': 'Timing analysis'},
#        {'name': 'Model-order reduction',
#         'children': [],
#         'parent': 'Timing analysis'},
#        {'name': 'Compact delay models',
#         'children': [],
#         'parent': 'Timing analysis'},
#        {'name': 'Static timing analysis',
#         'children': [],
#         'parent': 'Timing analysis'},
#        {'name': 'Statistical timing analysis',
#         'children': [],
#         'parent': 'Timing analysis'},
#        {'name': 'Transition-based timing analysis',
#         'children': [],
#         'parent': 'Timing analysis'}],
#       'parent': 'Electronic design automation'},
#      {'name': 'Methodologies for EDA',
#       'children': [{'name': 'Best practices for EDA',
#         'children': [],
#         'parent': 'Methodologies for EDA'},
#        {'name': 'Design databases for EDA',
#         'children': [],
#         'parent': 'Methodologies for EDA'},
#        {'name': 'Software tools for EDA',
#         'children': [],
#         'parent': 'Methodologies for EDA'}],
#       'parent': 'Electronic design automation'}],
#     'parent': 'Hardware'},
#    {'name': 'Hardware validation',
#     'children': [{'name': 'Functional verification',
#       'children': [{'name': 'Model checking',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Coverage metrics',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Equivalence checking',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Semi-formal verification',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Simulation and emulation',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Transaction-level verification',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Theorem proving and SAT solving',
#         'children': [],
#         'parent': 'Functional verification'},
#        {'name': 'Assertion checking',
#         'children': [],
#         'parent': 'Functional verification'}],
#       'parent': 'Hardware validation'},
#      {'name': 'Physical verification',
#       'children': [{'name': 'Design rule checking',
#         'children': [],
#         'parent': 'Physical verification'},
#        {'name': 'Layout-versus-schematics',
#         'children': [],
#         'parent': 'Physical verification'},
#        {'name': 'Power and thermal analysis',
#         'children': [],
#         'parent': 'Physical verification'},
#        {'name': 'Timing analysis and sign-off',
#         'children': [],
#         'parent': 'Physical verification'}],
#       'parent': 'Hardware validation'},
#      {'name': 'Post-manufacture validation and debug',
#       'children': [{'name': 'Bug detection, localization and diagnosis',
#         'children': [],
#         'parent': 'Post-manufacture validation and debug'},
#        {'name': 'Bug fixing (hardware)',
#         'children': [],
#         'parent': 'Post-manufacture validation and debug'},
#        {'name': 'Design for debug',
#         'children': [],
#         'parent': 'Post-manufacture validation and debug'}],
#       'parent': 'Hardware validation'}],
#     'parent': 'Hardware'},
#    {'name': 'Hardware test',
#     'children': [{'name': 'Analog, mixed-signal and radio frequency test',
#       'children': [],
#       'parent': 'Hardware test'},
#      {'name': 'Board- and system-level test',
#       'children': [],
#       'parent': 'Hardware test'},
#      {'name': 'Defect-based test', 'children': [], 'parent': 'Hardware test'},
#      {'name': 'Design for testability',
#       'children': [{'name': 'Built-in self-test',
#         'children': [],
#         'parent': 'Design for testability'},
#        {'name': 'Online test and diagnostics',
#         'children': [],
#         'parent': 'Design for testability'},
#        {'name': 'Test data compression',
#         'children': [],
#         'parent': 'Design for testability'}],
#       'parent': 'Hardware test'},
#      {'name': 'Fault models and test metrics',
#       'children': [],
#       'parent': 'Hardware test'},
#      {'name': 'Memory test and repair',
#       'children': [],
#       'parent': 'Hardware test'},
#      {'name': 'Hardware reliability screening',
#       'children': [],
#       'parent': 'Hardware test'},
#      {'name': 'Test-pattern generation and fault simulation',
#       'children': [],
#       'parent': 'Hardware test'},
#      {'name': 'Testing with distributed and parallel systems',
#       'children': [],
#       'parent': 'Hardware test'}],
#     'parent': 'Hardware'},
#    {'name': 'Robustness',
#     'children': [{'name': 'Fault tolerance',
#       'children': [{'name': 'Error detection and error correction',
#         'children': [],
#         'parent': 'Fault tolerance'},
#        {'name': 'Failure prediction',
#         'children': [],
#         'parent': 'Fault tolerance'},
#        {'name': 'Failure recovery, maintenance and self-repair',
#         'children': [],
#         'parent': 'Fault tolerance'},
#        {'name': 'Redundancy', 'children': [], 'parent': 'Fault tolerance'},
#        {'name': 'Self-checking mechanisms',
#         'children': [],
#         'parent': 'Fault tolerance'},
#        {'name': 'System-level fault tolerance',
#         'children': [],
#         'parent': 'Fault tolerance'}],
#       'parent': 'Robustness'},
#      {'name': 'Design for manufacturability',
#       'children': [{'name': 'Process variations',
#         'children': [],
#         'parent': 'Design for manufacturability'},
#        {'name': 'Yield and cost modeling',
#         'children': [],
#         'parent': 'Design for manufacturability'},
#        {'name': 'Yield and cost optimization',
#         'children': [],
#         'parent': 'Design for manufacturability'}],
#       'parent': 'Robustness'},
#      {'name': 'Hardware reliability',
#       'children': [{'name': 'Aging of circuits and systems',
#         'children': [],
#         'parent': 'Hardware reliability'},
#        {'name': 'Circuit hardening',
#         'children': [],
#         'parent': 'Hardware reliability'},
#        {'name': 'Early-life failures and infant mortality',
#         'children': [],
#         'parent': 'Hardware reliability'},
#        {'name': 'Process, voltage and temperature variations',
#         'children': [],
#         'parent': 'Hardware reliability'},
#        {'name': 'Signal integrity and noise analysis',
#         'children': [],
#         'parent': 'Hardware reliability'},
#        {'name': 'Transient errors and upsets',
#         'children': [],
#         'parent': 'Hardware reliability'}],
#       'parent': 'Robustness'},
#      {'name': 'Safety critical systems',
#       'children': [],
#       'parent': 'Robustness'}],
#     'parent': 'Hardware'},
#    {'name': 'Emerging technologies',
#     'children': [{'name': 'Analysis and design of emerging devices and systems',
#       'children': [{'name': 'Emerging architectures',
#         'children': [],
#         'parent': 'Analysis and design of emerging devices and systems'},
#        {'name': 'Emerging languages and compilers',
#         'children': [],
#         'parent': 'Analysis and design of emerging devices and systems'},
#        {'name': 'Emerging simulation',
#         'children': [],
#         'parent': 'Analysis and design of emerging devices and systems'},
#        {'name': 'Emerging tools and methodologies',
#         'children': [],
#         'parent': 'Analysis and design of emerging devices and systems'}],
#       'parent': 'Emerging technologies'},
#      {'name': 'Biology-related information processing',
#       'children': [{'name': 'Bio-embedded electronics',
#         'children': [],
#         'parent': 'Biology-related information processing'},
#        {'name': 'Neural systems',
#         'children': [],
#         'parent': 'Biology-related information processing'}],
#       'parent': 'Emerging technologies'},
#      {'name': 'Circuit substrates',
#       'children': [{'name': 'III-V compounds',
#         'children': [],
#         'parent': 'Circuit substrates'},
#        {'name': 'Carbon based electronics',
#         'children': [],
#         'parent': 'Circuit substrates'},
#        {'name': 'Cellular neural networks',
#         'children': [],
#         'parent': 'Circuit substrates'},
#        {'name': 'Flexible and printable circuits',
#         'children': [],
#         'parent': 'Circuit substrates'},
#        {'name': 'Superconducting circuits',
#         'children': [],
#         'parent': 'Circuit substrates'}],
#       'parent': 'Emerging technologies'},
#      {'name': 'Electromechanical systems',
#       'children': [{'name': 'Microelectromechanical systems',
#         'children': [],
#         'parent': 'Electromechanical systems'},
#        {'name': 'Nanoelectromechanical systems',
#         'children': [],
#         'parent': 'Electromechanical systems'}],
#       'parent': 'Emerging technologies'},
#      {'name': 'Emerging interfaces',
#       'children': [],
#       'parent': 'Emerging technologies'},
#      {'name': 'Memory and dense storage',
#       'children': [],
#       'parent': 'Emerging technologies'},
#      {'name': 'Emerging optical and photonic technologies',
#       'children': [],
#       'parent': 'Emerging technologies'},
#      {'name': 'Reversible logic',
#       'children': [],
#       'parent': 'Emerging technologies'},
#      {'name': 'Plasmonics', 'children': [], 'parent': 'Emerging technologies'},
#      {'name': 'Quantum technologies',
#       'children': [{'name': 'Single electron devices',
#         'children': [],
#         'parent': 'Quantum technologies'},
#        {'name': 'Tunneling devices',
#         'children': [],
#         'parent': 'Quantum technologies'},
#        {'name': 'Quantum computation',
#         'children': [{'name': 'Quantum communication and cryptography',
#           'children': [],
#           'parent': 'Quantum computation'},
#          {'name': 'Quantum error correction and fault tolerance',
#           'children': [],
#           'parent': 'Quantum computation'}],
#         'parent': 'Quantum technologies'},
#        {'name': 'Quantum dots and cellular automata',
#         'children': [],
#         'parent': 'Quantum technologies'}],
#       'parent': 'Emerging technologies'},
#      {'name': 'Spintronics and magnetic technologies',
#       'children': [],
#       'parent': 'Emerging technologies'}],
#     'parent': 'Hardware'}],
#   'parent': None},
#  {'name': 'Computer systems organization',
#   'children': [{'name': 'Architectures',
#     'children': [{'name': 'Serial architectures',
#       'children': [{'name': 'Reduced instruction set computing',
#         'children': [],
#         'parent': 'Serial architectures'},
#        {'name': 'Complex instruction set computing',
#         'children': [],
#         'parent': 'Serial architectures'},
#        {'name': 'Superscalar architectures',
#         'children': [],
#         'parent': 'Serial architectures'},
#        {'name': 'Pipeline computing',
#         'children': [],
#         'parent': 'Serial architectures'},
#        {'name': 'Stack machines',
#         'children': [],
#         'parent': 'Serial architectures'}],
#       'parent': 'Architectures'},
#      {'name': 'Parallel architectures',
#       'children': [{'name': 'Very long instruction word',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Interconnection architectures',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Multiple instruction, multiple data',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Cellular architectures',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Multiple instruction, single data',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Single instruction, multiple data',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Systolic arrays',
#         'children': [],
#         'parent': 'Parallel architectures'},
#        {'name': 'Multicore architectures',
#         'children': [],
#         'parent': 'Parallel architectures'}],
#       'parent': 'Architectures'},
#      {'name': 'Distributed architectures',
#       'children': [{'name': 'Cloud computing',
#         'children': [],
#         'parent': 'Distributed architectures'},
#        {'name': 'Client-server architectures',
#         'children': [],
#         'parent': 'Distributed architectures'},
#        {'name': 'n-tier architectures',
#         'children': [],
#         'parent': 'Distributed architectures'},
#        {'name': 'Peer-to-peer architectures',
#         'children': [],
#         'parent': 'Distributed architectures'},
#        {'name': 'Grid computing',
#         'children': [],
#         'parent': 'Distributed architectures'}],
#       'parent': 'Architectures'},
#      {'name': 'Other architectures',
#       'children': [{'name': 'Neural networks',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Reconfigurable computing',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Analog computers',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Data flow architectures',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Heterogeneous (hybrid) systems',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Self-organizing autonomic computing',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Optical computing',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Quantum computing',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Molecular computing',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'High-level language architectures',
#         'children': [],
#         'parent': 'Other architectures'},
#        {'name': 'Special purpose systems',
#         'children': [],
#         'parent': 'Other architectures'}],
#       'parent': 'Architectures'}],
#     'parent': 'Computer systems organization'},
#    {'name': 'Embedded and cyber-physical systems',
#     'children': [{'name': 'Sensor networks',
#       'children': [],
#       'parent': 'Embedded and cyber-physical systems'},
#      {'name': 'Robotics',
#       'children': [{'name': 'Robotic components',
#         'children': [],
#         'parent': 'Robotics'},
#        {'name': 'Robotic control',
#         'children': [{'name': 'Evolutionary robotics',
#           'children': [],
#           'parent': 'Robotic control'}],
#         'parent': 'Robotics'},
#        {'name': 'Robotic autonomy', 'children': [], 'parent': 'Robotics'},
#        {'name': 'External interfaces for robotics',
#         'children': [],
#         'parent': 'Robotics'}],
#       'parent': 'Embedded and cyber-physical systems'},
#      {'name': 'Sensors and actuators',
#       'children': [],
#       'parent': 'Embedded and cyber-physical systems'},
#      {'name': 'System on a chip',
#       'children': [],
#       'parent': 'Embedded and cyber-physical systems'},
#      {'name': 'Embedded systems',
#       'children': [{'name': 'Firmware',
#         'children': [],
#         'parent': 'Embedded systems'},
#        {'name': 'Embedded hardware',
#         'children': [],
#         'parent': 'Embedded systems'},
#        {'name': 'Embedded software',
#         'children': [],
#         'parent': 'Embedded systems'}],
#       'parent': 'Embedded and cyber-physical systems'}],
#     'parent': 'Computer systems organization'},
#    {'name': 'Real-time systems',
#     'children': [{'name': 'Real-time operating systems',
#       'children': [],
#       'parent': 'Real-time systems'},
#      {'name': 'Real-time languages',
#       'children': [],
#       'parent': 'Real-time systems'},
#      {'name': 'Real-time system specification',
#       'children': [],
#       'parent': 'Real-time systems'},
#      {'name': 'Real-time system architecture',
#       'children': [],
#       'parent': 'Real-time systems'}],
#     'parent': 'Computer systems organization'},
#    {'name': 'Dependable and fault-tolerant systems and networks',
#     'children': [{'name': 'Reliability',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'},
#      {'name': 'Availability',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'},
#      {'name': 'Maintainability and maintenance',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'},
#      {'name': 'Processors and memory architectures',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'},
#      {'name': 'Secondary storage organization',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'},
#      {'name': 'Redundancy',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'},
#      {'name': 'Fault-tolerant network topologies',
#       'children': [],
#       'parent': 'Dependable and fault-tolerant systems and networks'}],
#     'parent': 'Computer systems organization'}],
#   'parent': None},
#  {'name': 'Networks',
#   'children': [{'name': 'Network architectures',
#     'children': [{'name': 'Network design principles',
#       'children': [{'name': 'Layering',
#         'children': [],
#         'parent': 'Network design principles'},
#        {'name': 'Naming and addressing',
#         'children': [],
#         'parent': 'Network design principles'}],
#       'parent': 'Network architectures'},
#      {'name': 'Programming interfaces',
#       'children': [],
#       'parent': 'Network architectures'}],
#     'parent': 'Networks'},
#    {'name': 'Network protocols',
#     'children': [{'name': 'Network protocol design',
#       'children': [],
#       'parent': 'Network protocols'},
#      {'name': 'Protocol correctness',
#       'children': [{'name': 'Protocol testing and verification',
#         'children': [],
#         'parent': 'Protocol correctness'},
#        {'name': 'Formal specifications',
#         'children': [],
#         'parent': 'Protocol correctness'}],
#       'parent': 'Network protocols'},
#      {'name': 'Link-layer protocols',
#       'children': [],
#       'parent': 'Network protocols'},
#      {'name': 'Network layer protocols',
#       'children': [{'name': 'Routing protocols',
#         'children': [],
#         'parent': 'Network layer protocols'},
#        {'name': 'Signaling protocols',
#         'children': [],
#         'parent': 'Network layer protocols'}],
#       'parent': 'Network protocols'},
#      {'name': 'Transport protocols',
#       'children': [],
#       'parent': 'Network protocols'},
#      {'name': 'Session protocols',
#       'children': [],
#       'parent': 'Network protocols'},
#      {'name': 'Presentation protocols',
#       'children': [],
#       'parent': 'Network protocols'},
#      {'name': 'Application layer protocols',
#       'children': [{'name': 'Peer-to-peer protocols',
#         'children': [],
#         'parent': 'Application layer protocols'}],
#       'parent': 'Network protocols'},
#      {'name': 'OAM protocols',
#       'children': [{'name': 'Time synchronization protocols',
#         'children': [],
#         'parent': 'OAM protocols'},
#        {'name': 'Network policy', 'children': [], 'parent': 'OAM protocols'}],
#       'parent': 'Network protocols'},
#      {'name': 'Cross-layer protocols',
#       'children': [],
#       'parent': 'Network protocols'},
#      {'name': 'Network File System (NFS) protocol',
#       'children': [],
#       'parent': 'Network protocols'}],
#     'parent': 'Networks'},
#    {'name': 'Network components',
#     'children': [{'name': 'Intermediate nodes',
#       'children': [{'name': 'Routers',
#         'children': [],
#         'parent': 'Intermediate nodes'},
#        {'name': 'Bridges and switches',
#         'children': [],
#         'parent': 'Intermediate nodes'}],
#       'parent': 'Network components'},
#      {'name': 'Physical links',
#       'children': [{'name': 'Repeaters',
#         'children': [],
#         'parent': 'Physical links'}],
#       'parent': 'Network components'},
#      {'name': 'Middle boxes / network appliances',
#       'children': [],
#       'parent': 'Network components'},
#      {'name': 'End nodes',
#       'children': [{'name': 'Network adapters',
#         'children': [],
#         'parent': 'End nodes'},
#        {'name': 'Network servers', 'children': [], 'parent': 'End nodes'}],
#       'parent': 'Network components'},
#      {'name': 'Wireless access points, base stations and infrastructure',
#       'children': [{'name': 'Cognitive radios',
#         'children': [],
#         'parent': 'Wireless access points, base stations and infrastructure'}],
#       'parent': 'Network components'},
#      {'name': 'Logical nodes',
#       'children': [{'name': 'Network domains',
#         'children': [],
#         'parent': 'Logical nodes'}],
#       'parent': 'Network components'}],
#     'parent': 'Networks'},
#    {'name': 'Network algorithms',
#     'children': [{'name': 'Data path algorithms',
#       'children': [{'name': 'Packet classification',
#         'children': [],
#         'parent': 'Data path algorithms'},
#        {'name': 'Deep packet inspection',
#         'children': [],
#         'parent': 'Data path algorithms'},
#        {'name': 'Packet scheduling',
#         'children': [],
#         'parent': 'Data path algorithms'}],
#       'parent': 'Network algorithms'},
#      {'name': 'Control path algorithms',
#       'children': [{'name': 'Network resources allocation',
#         'children': [],
#         'parent': 'Control path algorithms'},
#        {'name': 'Network control algorithms',
#         'children': [],
#         'parent': 'Control path algorithms'},
#        {'name': 'Traffic engineering algorithms',
#         'children': [],
#         'parent': 'Control path algorithms'},
#        {'name': 'Network design and planning algorithms',
#         'children': [],
#         'parent': 'Control path algorithms'}],
#       'parent': 'Network algorithms'},
#      {'name': 'Network economics',
#       'children': [],
#       'parent': 'Network algorithms'}],
#     'parent': 'Networks'},
#    {'name': 'Network performance evaluation',
#     'children': [{'name': 'Network performance modeling',
#       'children': [],
#       'parent': 'Network performance evaluation'},
#      {'name': 'Network simulations',
#       'children': [],
#       'parent': 'Network performance evaluation'},
#      {'name': 'Network experimentation',
#       'children': [],
#       'parent': 'Network performance evaluation'},
#      {'name': 'Network performance analysis',
#       'children': [],
#       'parent': 'Network performance evaluation'},
#      {'name': 'Network measurement',
#       'children': [],
#       'parent': 'Network performance evaluation'}],
#     'parent': 'Networks'},
#    {'name': 'Network properties',
#     'children': [{'name': 'Network security',
#       'children': [{'name': 'Security protocols',
#         'children': [],
#         'parent': 'Network security'},
#        {'name': 'Web protocol security',
#         'children': [],
#         'parent': 'Network security'},
#        {'name': 'Mobile and wireless security',
#         'children': [],
#         'parent': 'Network security'},
#        {'name': 'Denial-of-service attacks',
#         'children': [],
#         'parent': 'Network security'},
#        {'name': 'Firewalls', 'children': [], 'parent': 'Network security'}],
#       'parent': 'Network properties'},
#      {'name': 'Network range',
#       'children': [{'name': 'Short-range networks',
#         'children': [],
#         'parent': 'Network range'},
#        {'name': 'Local area networks',
#         'children': [],
#         'parent': 'Network range'},
#        {'name': 'Metropolitan area networks',
#         'children': [],
#         'parent': 'Network range'},
#        {'name': 'Wide area networks',
#         'children': [],
#         'parent': 'Network range'},
#        {'name': 'Very long-range networks',
#         'children': [],
#         'parent': 'Network range'}],
#       'parent': 'Network properties'},
#      {'name': 'Network structure',
#       'children': [{'name': 'Topology analysis and generation',
#         'children': [],
#         'parent': 'Network structure'},
#        {'name': 'Physical topologies',
#         'children': [],
#         'parent': 'Network structure'},
#        {'name': 'Logical / virtual topologies',
#         'children': [],
#         'parent': 'Network structure'},
#        {'name': 'Network topology types',
#         'children': [{'name': 'Point-to-point networks',
#           'children': [],
#           'parent': 'Network topology types'},
#          {'name': 'Bus networks',
#           'children': [],
#           'parent': 'Network topology types'},
#          {'name': 'Star networks',
#           'children': [],
#           'parent': 'Network topology types'},
#          {'name': 'Ring networks',
#           'children': [{'name': 'Token ring networks',
#             'children': [],
#             'parent': 'Ring networks'},
#            {'name': 'Fiber distributed data interface (FDDI)',
#             'children': [],
#             'parent': 'Ring networks'}],
#           'parent': 'Network topology types'},
#          {'name': 'Mesh networks',
#           'children': [{'name': 'Wireless mesh networks',
#             'children': [],
#             'parent': 'Mesh networks'}],
#           'parent': 'Network topology types'},
#          {'name': 'Hybrid networks',
#           'children': [],
#           'parent': 'Network topology types'}],
#         'parent': 'Network structure'}],
#       'parent': 'Network properties'},
#      {'name': 'Network dynamics',
#       'children': [],
#       'parent': 'Network properties'},
#      {'name': 'Network reliability',
#       'children': [{'name': 'Error detection and error correction',
#         'children': [],
#         'parent': 'Network reliability'}],
#       'parent': 'Network properties'},
#      {'name': 'Network mobility',
#       'children': [],
#       'parent': 'Network properties'},
#      {'name': 'Network manageability',
#       'children': [],
#       'parent': 'Network properties'},
#      {'name': 'Network privacy and anonymity',
#       'children': [],
#       'parent': 'Network properties'}],
#     'parent': 'Networks'},
#    {'name': 'Network services',
#     'children': [{'name': 'Naming and addressing',
#       'children': [],
#       'parent': 'Network services'},
#      {'name': 'Cloud computing', 'children': [], 'parent': 'Network services'},
#      {'name': 'Location based services',
#       'children': [],
#       'parent': 'Network services'},
#      {'name': 'Programmable networks',
#       'children': [],
#       'parent': 'Network services'},
#      {'name': 'In-network processing',
#       'children': [],
#       'parent': 'Network services'},
#      {'name': 'Network management',
#       'children': [],
#       'parent': 'Network services'},
#      {'name': 'Network monitoring',
#       'children': [],
#       'parent': 'Network services'}],
#     'parent': 'Networks'},
#    {'name': 'Network types',
#     'children': [{'name': 'Network on chip',
#       'children': [],
#       'parent': 'Network types'},
#      {'name': 'Home networks', 'children': [], 'parent': 'Network types'},
#      {'name': 'Storage area networks',
#       'children': [],
#       'parent': 'Network types'},
#      {'name': 'Data center networks',
#       'children': [],
#       'parent': 'Network types'},
#      {'name': 'Wired access networks',
#       'children': [],
#       'parent': 'Network types'},
#      {'name': 'Cyber-physical networks',
#       'children': [{'name': 'Sensor networks',
#         'children': [],
#         'parent': 'Cyber-physical networks'}],
#       'parent': 'Network types'},
#      {'name': 'Mobile networks', 'children': [], 'parent': 'Network types'},
#      {'name': 'Overlay and other logical network structures',
#       'children': [{'name': 'Peer-to-peer networks',
#         'children': [],
#         'parent': 'Overlay and other logical network structures'},
#        {'name': 'World Wide Web (network structure)',
#         'children': [],
#         'parent': 'Overlay and other logical network structures'},
#        {'name': 'Social media networks',
#         'children': [],
#         'parent': 'Overlay and other logical network structures'},
#        {'name': 'Online social networks',
#         'children': [],
#         'parent': 'Overlay and other logical network structures'}],
#       'parent': 'Network types'},
#      {'name': 'Wireless access networks',
#       'children': [{'name': 'Wireless local area networks',
#         'children': [],
#         'parent': 'Wireless access networks'},
#        {'name': 'Wireless personal area networks',
#         'children': [],
#         'parent': 'Wireless access networks'}],
#       'parent': 'Network types'},
#      {'name': 'Ad hoc networks',
#       'children': [{'name': 'Mobile ad hoc networks',
#         'children': [],
#         'parent': 'Ad hoc networks'}],
#       'parent': 'Network types'},
#      {'name': 'Public Internet', 'children': [], 'parent': 'Network types'},
#      {'name': 'Packet-switching networks',
#       'children': [],
#       'parent': 'Network types'}],
#     'parent': 'Networks'}],
#   'parent': None},
#  {'name': 'Software and its engineering',
#   'children': [{'name': 'Software organization and properties',
#     'children': [{'name': 'Contextual software domains',
#       'children': [{'name': 'E-commerce infrastructure',
#         'children': [],
#         'parent': 'Contextual software domains'},
#        {'name': 'Software infrastructure',
#         'children': [{'name': 'Interpreters',
#           'children': [],
#           'parent': 'Software infrastructure'},
#          {'name': 'Middleware',
#           'children': [{'name': 'Message oriented middleware',
#             'children': [],
#             'parent': 'Middleware'},
#            {'name': 'Reflective middleware',
#             'children': [],
#             'parent': 'Middleware'},
#            {'name': 'Embedded middleware',
#             'children': [],
#             'parent': 'Middleware'}],
#           'parent': 'Software infrastructure'},
#          {'name': 'Virtual machines',
#           'children': [],
#           'parent': 'Software infrastructure'}],
#         'parent': 'Contextual software domains'},
#        {'name': 'Operating systems',
#         'children': [{'name': 'File systems management',
#           'children': [],
#           'parent': 'Operating systems'},
#          {'name': 'Memory management',
#           'children': [{'name': 'Virtual memory',
#             'children': [],
#             'parent': 'Memory management'},
#            {'name': 'Main memory',
#             'children': [],
#             'parent': 'Memory management'},
#            {'name': 'Allocation / deallocation strategies',
#             'children': [],
#             'parent': 'Memory management'},
#            {'name': 'Garbage collection',
#             'children': [],
#             'parent': 'Memory management'},
#            {'name': 'Distributed memory',
#             'children': [],
#             'parent': 'Memory management'},
#            {'name': 'Secondary storage',
#             'children': [],
#             'parent': 'Memory management'}],
#           'parent': 'Operating systems'},
#          {'name': 'Process management',
#           'children': [{'name': 'Scheduling',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Deadlocks',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Multithreading',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Multiprocessing / multiprogramming / multitasking',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Monitors',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Mutual exclusion',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Concurrency control',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Power management',
#             'children': [],
#             'parent': 'Process management'},
#            {'name': 'Process synchronization',
#             'children': [],
#             'parent': 'Process management'}],
#           'parent': 'Operating systems'},
#          {'name': 'Communications management',
#           'children': [{'name': 'Buffering',
#             'children': [],
#             'parent': 'Communications management'},
#            {'name': 'Input / output',
#             'children': [],
#             'parent': 'Communications management'},
#            {'name': 'Message passing',
#             'children': [],
#             'parent': 'Communications management'}],
#           'parent': 'Operating systems'}],
#         'parent': 'Contextual software domains'},
#        {'name': 'Virtual worlds software',
#         'children': [{'name': 'Interactive games',
#           'children': [],
#           'parent': 'Virtual worlds software'},
#          {'name': 'Virtual worlds training simulations',
#           'children': [],
#           'parent': 'Virtual worlds software'}],
#         'parent': 'Contextual software domains'}],
#       'parent': 'Software organization and properties'},
#      {'name': 'Software system structures',
#       'children': [{'name': 'Embedded software',
#         'children': [],
#         'parent': 'Software system structures'},
#        {'name': 'Software architectures',
#         'children': [{'name': 'n-tier architectures',
#           'children': [],
#           'parent': 'Software architectures'},
# ...
#           'parent': 'Reinforcement learning'}],
#         'parent': 'Learning paradigms'},
#        {'name': 'Multi-task learning',
#         'children': [{'name': 'Transfer learning',
#           'children': [],
#           'parent': 'Multi-task learning'},
#          {'name': 'Lifelong machine learning',
#           'children': [],
#           'parent': 'Multi-task learning'},
#          {'name': 'Learning under covariate shift',
#           'children': [],
#           'parent': 'Multi-task learning'}],
#         'parent': 'Learning paradigms'}],
#       'parent': 'Machine learning'},
#      {'name': 'Learning settings',
#       'children': [{'name': 'Batch learning',
#         'children': [],
#         'parent': 'Learning settings'},
#        {'name': 'Online learning settings',
#         'children': [],
#         'parent': 'Learning settings'},
#        {'name': 'Learning from demonstrations',
#         'children': [],
#         'parent': 'Learning settings'},
#        {'name': 'Learning from critiques',
#         'children': [],
#         'parent': 'Learning settings'},
#        {'name': 'Learning from implicit feedback',
#         'children': [],
#         'parent': 'Learning settings'},
#        {'name': 'Active learning settings',
#         'children': [],
#         'parent': 'Learning settings'},
#        {'name': 'Semi-supervised learning settings',
#         'children': [],
#         'parent': 'Learning settings'}],
#       'parent': 'Machine learning'},
#      {'name': 'Machine learning approaches',
#       'children': [{'name': 'Classification and regression trees',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Kernel methods',
#         'children': [{'name': 'Support vector machines',
#           'children': [],
#           'parent': 'Kernel methods'},
#          {'name': 'Gaussian processes',
#           'children': [],
#           'parent': 'Kernel methods'}],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Neural networks',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Logical and relational learning',
#         'children': [{'name': 'Inductive logic learning',
#           'children': [],
#           'parent': 'Logical and relational learning'},
#          {'name': 'Statistical relational learning',
#           'children': [],
#           'parent': 'Logical and relational learning'}],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Learning in probabilistic graphical models',
#         'children': [{'name': 'Maximum likelihood modeling',
#           'children': [],
#           'parent': 'Learning in probabilistic graphical models'},
#          {'name': 'Maximum entropy modeling',
#           'children': [],
#           'parent': 'Learning in probabilistic graphical models'},
#          {'name': 'Maximum a posteriori modeling',
#           'children': [],
#           'parent': 'Learning in probabilistic graphical models'},
#          {'name': 'Mixture models',
#           'children': [],
#           'parent': 'Learning in probabilistic graphical models'},
#          {'name': 'Latent variable models',
#           'children': [],
#           'parent': 'Learning in probabilistic graphical models'},
#          {'name': 'Bayesian network models',
#           'children': [],
#           'parent': 'Learning in probabilistic graphical models'}],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Learning linear models',
#         'children': [{'name': 'Perceptron algorithm',
#           'children': [],
#           'parent': 'Learning linear models'}],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Factorization methods',
#         'children': [{'name': 'Non-negative matrix factorization',
#           'children': [],
#           'parent': 'Factorization methods'},
#          {'name': 'Factor analysis',
#           'children': [],
#           'parent': 'Factorization methods'},
#          {'name': 'Principal component analysis',
#           'children': [],
#           'parent': 'Factorization methods'},
#          {'name': 'Canonical correlation analysis',
#           'children': [],
#           'parent': 'Factorization methods'},
#          {'name': 'Latent Dirichlet allocation',
#           'children': [],
#           'parent': 'Factorization methods'}],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Rule learning',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Instance-based learning',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Markov decision processes',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Partially-observable Markov decision processes',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Stochastic games',
#         'children': [],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Learning latent representations',
#         'children': [{'name': 'Deep belief networks',
#           'children': [],
#           'parent': 'Learning latent representations'}],
#         'parent': 'Machine learning approaches'},
#        {'name': 'Bio-inspired approaches',
#         'children': [{'name': 'Artificial life',
#           'children': [],
#           'parent': 'Bio-inspired approaches'},
#          {'name': 'Evolvable hardware',
#           'children': [],
#           'parent': 'Bio-inspired approaches'},
#          {'name': 'Genetic algorithms',
#           'children': [],
#           'parent': 'Bio-inspired approaches'},
#          {'name': 'Genetic programming',
#           'children': [],
#           'parent': 'Bio-inspired approaches'},
#          {'name': 'Evolutionary robotics',
#           'children': [],
#           'parent': 'Bio-inspired approaches'},
#          {'name': 'Generative and developmental approaches',
#           'children': [],
#           'parent': 'Bio-inspired approaches'}],
#         'parent': 'Machine learning approaches'}],
#       'parent': 'Machine learning'},
#      {'name': 'Machine learning algorithms',
#       'children': [{'name': 'Dynamic programming for Markov decision processes',
#         'children': [{'name': 'Value iteration',
#           'children': [],
#           'parent': 'Dynamic programming for Markov decision processes'},
#          {'name': 'Q-learning',
#           'children': [],
#           'parent': 'Dynamic programming for Markov decision processes'},
#          {'name': 'Policy iteration',
#           'children': [],
#           'parent': 'Dynamic programming for Markov decision processes'},
#          {'name': 'Temporal difference learning',
#           'children': [],
#           'parent': 'Dynamic programming for Markov decision processes'},
#          {'name': 'Approximate dynamic programming methods',
#           'children': [],
#           'parent': 'Dynamic programming for Markov decision processes'}],
#         'parent': 'Machine learning algorithms'},
#        {'name': 'Ensemble methods',
#         'children': [{'name': 'Boosting',
#           'children': [],
#           'parent': 'Ensemble methods'},
#          {'name': 'Bagging', 'children': [], 'parent': 'Ensemble methods'}],
#         'parent': 'Machine learning algorithms'},
#        {'name': 'Spectral methods',
#         'children': [],
#         'parent': 'Machine learning algorithms'},
#        {'name': 'Feature selection',
#         'children': [],
#         'parent': 'Machine learning algorithms'},
#        {'name': 'Regularization',
#         'children': [],
#         'parent': 'Machine learning algorithms'}],
#       'parent': 'Machine learning'},
#      {'name': 'Cross-validation',
#       'children': [],
#       'parent': 'Machine learning'}],
#     'parent': 'Artificial intelligence'},
#    {'name': 'Modeling and simulation',
#     'children': [{'name': 'Model development and analysis',
#       'children': [{'name': 'Modeling methodologies',
#         'children': [],
#         'parent': 'Model development and analysis'},
#        {'name': 'Model verification and validation',
#         'children': [],
#         'parent': 'Model development and analysis'},
#        {'name': 'Uncertainty quantification',
#         'children': [],
#         'parent': 'Model development and analysis'}],
#       'parent': 'Modeling and simulation'},
#      {'name': 'Simulation theory',
#       'children': [{'name': 'Systems theory',
#         'children': [],
#         'parent': 'Simulation theory'},
#        {'name': 'Network science',
#         'children': [],
#         'parent': 'Simulation theory'}],
#       'parent': 'Modeling and simulation'},
#      {'name': 'Simulation types and techniques',
#       'children': [{'name': 'Uncertainty quantification',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Quantum mechanic simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Molecular simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Rare-event simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Discrete-event simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Agent / discrete models',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Distributed simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Continuous simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Continuous models',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Real-time simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Interactive simulation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Multiscale systems',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Massively parallel and high-performance simulations',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Data assimilation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Scientific visualization',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Visual analytics',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Simulation by animation',
#         'children': [],
#         'parent': 'Simulation types and techniques'},
#        {'name': 'Artificial life',
#         'children': [],
#         'parent': 'Simulation types and techniques'}],
#       'parent': 'Modeling and simulation'},
#      {'name': 'Simulation support systems',
#       'children': [{'name': 'Simulation environments',
#         'children': [],
#         'parent': 'Simulation support systems'},
#        {'name': 'Simulation languages',
#         'children': [],
#         'parent': 'Simulation support systems'},
#        {'name': 'Simulation tools',
#         'children': [],
#         'parent': 'Simulation support systems'}],
#       'parent': 'Modeling and simulation'},
#      {'name': 'Simulation evaluation',
#       'children': [],
#       'parent': 'Modeling and simulation'}],
#     'parent': 'Artificial intelligence'}],
#   'parent': None},
#  {'name': 'Parallel computing methodologies',
#   'children': [{'name': 'Parallel algorithms',
#     'children': [{'name': 'MapReduce algorithms',
#       'children': [],
#       'parent': 'Parallel algorithms'},
#      {'name': 'Self-organization',
#       'children': [],
#       'parent': 'Parallel algorithms'},
#      {'name': 'Shared memory algorithms',
#       'children': [],
#       'parent': 'Parallel algorithms'},
#      {'name': 'Vector / streaming algorithms',
#       'children': [],
#       'parent': 'Parallel algorithms'},
#      {'name': 'Massively parallel algorithms',
#       'children': [],
#       'parent': 'Parallel algorithms'}],
#     'parent': 'Parallel computing methodologies'},
#    {'name': 'Parallel programming languages',
#     'children': [],
#     'parent': 'Parallel computing methodologies'}],
#   'parent': None},
#  {'name': 'Computer graphics',
#   'children': [{'name': 'Animation',
#     'children': [{'name': 'Motion capture',
#       'children': [],
#       'parent': 'Animation'},
#      {'name': 'Procedural animation', 'children': [], 'parent': 'Animation'},
#      {'name': 'Physical simulation', 'children': [], 'parent': 'Animation'},
#      {'name': 'Motion processing', 'children': [], 'parent': 'Animation'},
#      {'name': 'Collision detection', 'children': [], 'parent': 'Animation'}],
#     'parent': 'Computer graphics'},
#    {'name': 'Rendering',
#     'children': [{'name': 'Rasterization',
#       'children': [],
#       'parent': 'Rendering'},
#      {'name': 'Ray tracing', 'children': [], 'parent': 'Rendering'},
#      {'name': 'Non-photorealistic rendering',
#       'children': [],
#       'parent': 'Rendering'},
#      {'name': 'Reflectance modeling', 'children': [], 'parent': 'Rendering'},
#      {'name': 'Visibility', 'children': [], 'parent': 'Rendering'}],
#     'parent': 'Computer graphics'},
#    {'name': 'Image manipulation',
#     'children': [{'name': 'Computational photography',
#       'children': [],
#       'parent': 'Image manipulation'},
#      {'name': 'Image processing',
#       'children': [],
#       'parent': 'Image manipulation'},
#      {'name': 'Texturing', 'children': [], 'parent': 'Image manipulation'},
#      {'name': 'Image-based rendering',
#       'children': [],
#       'parent': 'Image manipulation'},
#      {'name': 'Antialiasing', 'children': [], 'parent': 'Image manipulation'}],
#     'parent': 'Computer graphics'},
#    {'name': 'Graphics systems and interfaces',
#     'children': [{'name': 'Graphics processors',
#       'children': [],
#       'parent': 'Graphics systems and interfaces'},
#      {'name': 'Graphics input devices',
#       'children': [],
#       'parent': 'Graphics systems and interfaces'},
#      {'name': 'Mixed / augmented reality',
#       'children': [],
#       'parent': 'Graphics systems and interfaces'},
#      {'name': 'Perception',
#       'children': [],
#       'parent': 'Graphics systems and interfaces'},
#      {'name': 'Graphics file formats',
#       'children': [],
#       'parent': 'Graphics systems and interfaces'},
#      {'name': 'Virtual reality',
#       'children': [],
#       'parent': 'Graphics systems and interfaces'}],
#     'parent': 'Computer graphics'},
#    {'name': 'Image compression',
#     'children': [],
#     'parent': 'Computer graphics'},
#    {'name': 'Shape modeling',
#     'children': [{'name': 'Mesh models',
#       'children': [],
#       'parent': 'Shape modeling'},
#      {'name': 'Mesh geometry models',
#       'children': [],
#       'parent': 'Shape modeling'},
#      {'name': 'Parametric curve and surface models',
#       'children': [],
#       'parent': 'Shape modeling'},
#      {'name': 'Point-based models',
#       'children': [],
#       'parent': 'Shape modeling'},
#      {'name': 'Volumetric models', 'children': [], 'parent': 'Shape modeling'},
#      {'name': 'Shape analysis', 'children': [], 'parent': 'Shape modeling'}],
#     'parent': 'Computer graphics'}],
#   'parent': None},
#  {'name': 'Distributed computing methodologies',
#   'children': [{'name': 'Distributed algorithms',
#     'children': [{'name': 'MapReduce algorithms',
#       'children': [],
#       'parent': 'Distributed algorithms'},
#      {'name': 'Self-organization',
#       'children': [],
#       'parent': 'Distributed algorithms'}],
#     'parent': 'Distributed computing methodologies'},
#    {'name': 'Distributed programming languages',
#     'children': [],
#     'parent': 'Distributed computing methodologies'}],
#   'parent': None},
#  {'name': 'Concurrent computing methodologies',
#   'children': [{'name': 'Concurrent programming languages',
#     'children': [],
#     'parent': 'Concurrent computing methodologies'},
#    {'name': 'Concurrent algorithms',
#     'children': [],
#     'parent': 'Concurrent computing methodologies'}],
#   'parent': None}]

# %%
# show depths for each category
for general_category in output:
    print('{}: Max Depth =  {}'.format(general_category['name'], max_depth([general_category], 0)))
# Out:
# Hardware: Max Depth =  5
# Computer systems organization: Max Depth =  5
# Networks: Max Depth =  6
# Software and its engineering: Max Depth =  6
# Theory of computation: Max Depth =  6
# Mathematics of computing: Max Depth =  6
# Information systems: Max Depth =  5
# Security and privacy: Max Depth =  4
# Human computer interaction (HCI): Max Depth =  4
# Applied computing: Max Depth =  5
# Social and professional topics: Max Depth =  6
# Artificial intelligence: Max Depth =  5
# Parallel computing methodologies: Max Depth =  3
# Computer graphics: Max Depth =  3
# Distributed computing methodologies: Max Depth =  3
# Concurrent computing methodologies: Max Depth =  2

# %%
get_nodes_at_depth(output, None, 1, 1)
# Out:
# Nodes for None
# Hardware
# Computer systems organization
# Networks
# Software and its engineering
# Theory of computation
# Mathematics of computing
# Information systems
# Security and privacy
# Human computer interaction (HCI)
# Applied computing
# Social and professional topics
# Artificial intelligence
# Parallel computing methodologies
# Computer graphics
# Distributed computing methodologies
# Concurrent computing methodologies

# %%
get_nodes_at_depth(output, None, 1, 2)
# Out:
# Nodes for Hardware
# Printed circuit boards
# Communication hardware, interfaces and storage
# Integrated circuits
# Very large scale integration design
# Power and energy
# Electronic design automation
# Hardware validation
# Hardware test
# Robustness
# Emerging technologies
#
# Nodes for Computer systems organization
# Architectures
# Embedded and cyber-physical systems
# Real-time systems
# Dependable and fault-tolerant systems and networks
#
# Nodes for Networks
# Network architectures
# Network protocols
# Network components
# Network algorithms
# Network performance evaluation
# Network properties
# Network services
# Network types
#
# Nodes for Software and its engineering
# Software organization and properties
# Software notations and tools
# Software creation and management
#
# Nodes for Theory of computation
# Models of computation
# Formal languages and automata theory
# Computational complexity and cryptography
# Logic
# Design and analysis of algorithms
# Randomness, geometry and discrete structures
# Theory and algorithms for application domains
# Semantics and reasoning
#
# Nodes for Mathematics of computing
# Discrete mathematics
# Probability and statistics
# Mathematical software
# Information theory
# Mathematical analysis
# Continuous mathematics
#
# Nodes for Information systems
# Data management systems
# Information storage systems
# Information systems applications
# World Wide Web
# Information retrieval
#
# Nodes for Security and privacy
# Cryptography
# Formal methods and theory of security
# Security services
# Intrusion/anomaly detection and malware mitigation
# Security in hardware
# Systems security
# Network security
# Database and storage security
# Software and application security
# Human and societal aspects of security and privacy
#
# Nodes for Human computer interaction (HCI)
# HCI design and evaluation methods
# Interaction paradigms
# Interaction devices
# HCI theory, concepts and models
# Interaction techniques
# Interactive systems and tools
# Empirical studies in HCI
# Interaction design
# Collaborative and social computing
# Ubiquitous and mobile computing
# Visualization
# Accessibility
#
# Nodes for Applied computing
# Electronic commerce
# Enterprise computing
# Physical sciences and engineering
# Life and medical sciences
# Law, social and behavioral sciences
# Computer forensics
# Arts and humanities
# Computers in other domains
# Operations research
# Education
# Document management and text processing
#
# Nodes for Social and professional topics
# Professional topics
# Computing / technology policy
# User characteristics
#
# Nodes for Artificial intelligence
# Natural language processing
# Knowledge representation and reasoning
# Planning and scheduling
# Search methodologies
# Control methods
# Philosophical/theoretical foundations of artificial intelligence
# Distributed artificial intelligence
# Computer vision
# Symbolic and algebraic manipulation
# Machine learning
# Modeling and simulation
#
# Nodes for Parallel computing methodologies
# Parallel algorithms
# Parallel programming languages
#
# Nodes for Computer graphics
# Animation
# Rendering
# Image manipulation
# Graphics systems and interfaces
# Image compression
# Shape modeling
#
# Nodes for Distributed computing methodologies
# Distributed algorithms
# Distributed programming languages
#
# Nodes for Concurrent computing methodologies
# Concurrent programming languages
# Concurrent algorithms

# %% [markdown]
# # Generate KRF From Scraped Data
# Example predicates that should be generated:
# ```
# (isa ML-Topic AcademicTopic)
# (subTopic ML-Topic AI-Topic)
# ```

# %%
def clean_topic_name(topic_name):
    # remove any text between parens
    cleaned_topic_name = re.sub("([\(\[]).*?([\)\]])", "\g<1>\g<2>", topic_name)
    
    # remove any puncutation and convert to lowercase
    cleaned_topic_name = cleaned_topic_name.translate(str.maketrans(string.punctuation, ' '*len(string.punctuation))).lower()
    
    # remove stop words and make CamelCase
    cleaned_topic_name = ''.join([word.title() for word in cleaned_topic_name.split() if not word.isspace() and word not in stops])
    
    return cleaned_topic_name


def generate_krf_as_list(tree, krf_list):
    # base case: no more children
    if len(tree) == 0:
        return krf_list
    
    # recurse deeper
    for child in tree:
        curr_child_name = clean_topic_name(child['name'])
        krf_list.append('(isa {} AcademicTopic)'.format(curr_child_name))
        
        if child['parent'] is not None:
            curr_parent_name = clean_topic_name(child['parent'])
            krf_list.append('(subTopic {} {})'.format(curr_child_name, curr_parent_name))
            
        krf_list = generate_krf_as_list(child['children'], krf_list)
    
    return krf_list

# %%
krf_list = generate_krf_as_list(output, [])
with open('../academic-fields.krf', 'w') as f:
    f.write('(in-microtheory TeachingKioskMt)\n\n')
    f.write('\n'.join(krf_list))
